# %%
import csv

# %%
with open("salaries.csv") as f:
    for line in csv.reader(f):
        print line
# Out:
# ['Gender', 'Experience', 'Salary']
# ['Female', '15', '78200']
# ['Female', '12', '66400']
# ['Female', '15', '61200']
# ['Female', '3', '61000']
# ['Female', '4', '60000']
# ['Female', '4', '68000']
# ['Female', '9', '59000']
# ['Female', '11', '53600']
# ['Female', '16', '62600']
# ['Female', '9', '62400']
# ['Female', '16', '69400']
# ['Female', '4', '60000']
# ['Female', '3', '62000']
# ['Female', '6', '54000']
# ['Female', '17', '59200']
# ['Female', '11', '65200']
# ['Female', '7', '59200']
# ['Female', '6', '59000']
# ['Female', '5', '57000']
# ['Female', '22', '84400']
# ['Female', '13', '75200']
# ['Female', '18', '68000']
# ['Female', '11', '66000']
# ['Female', '11', '57520']
# ['Female', '11', '70800']
# ['Female', '20', '77600']
# ['Female', '14', '68600']
# ['Female', '19', '70000']
# ['Female', '5', '69200']
# ['Female', '6', '57000']
# ['Female', '11', '59000']
# ['Female', '6', '68400']
# ['Female', '15', '87200']
# ['Female', '7', '67000']
# ...

# %%
w
